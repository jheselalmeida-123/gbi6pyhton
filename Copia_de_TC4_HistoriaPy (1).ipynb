# %% [markdown]
# ##**Historia del creador de Python**
#
# Van Rossum nació en 1956 en los Países bajos, posee un título en la maestria de matemáticas y ciencias de la computación de la Universidad de Amsterdam.

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from PIL import Image
from io import BytesIO

# URL de la imagen
url = "https://i.blogs.es/43f32c/van_rossum/1366_2000.jpg"

# Descargar la imagen usando requests
response = requests.get(url)

# Abrir la imagen en Pillow
img = Image.open(BytesIO(response.content))

# Mostrar la imagen
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x720 at 0x7F09736E2890>

# %% [markdown]
# ##**¿Por qué se llama Python?**
#
# Esta denominación al lenguaje de programación Python proviene de Monty Python, un grupo de cómicos británicos.

# %%
import requests
from PIL import Image
from io import BytesIO

# URL de la imagen
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png"
# Descargar la imagen usando requests
response = requests.get(url)

# Abrir la imagen en Pillow
img = Image.open(BytesIO(response.content))

# Mostrar la imagen
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x1315 at 0x7F097344FCA0>

# %% [markdown]
# ##**¿Cómo surgió Python?**
#
# Durante la época navideña en 1989 Van Rossum que en ese entonces trabajaba en un centro de Investigación holandés (CWI), tomo la iniciativa para empezar un proyecto nuevo, todo con fines de entretenimiento y pasatiempo personal. Ideo una continuidad a ABC, que es un lenguaje de programación desarrollado por él para el centro al que trabajaba. ABC fue desarrollado a inicios de los 80s como una opción a BASIC (Challenger-Pérez, 2014).
#
#
# **Ventajas en Python:**
#
# *   Es un lenguaje rápido y simplificado para scripting.
# *   Es legible y fácil de interpretar.
# *   Posee un sistema legible y organizado.
# *   Tiene un lenguaje portable, usado en cualquier sistema de la actualidad.

# %% [markdown]
# <A href="https://platzi.com/blog/historia-python/">Historia de Python
# </A>

# %% [markdown]
# ##**Versiones de Python:**
#
# Version 1.0
#
# Python 1.6.1 es lo mismo que 1.6, con bugs arreglados y licencia compatible con GPL.
#
# Version 2.0
#
# Se creo en el año 2000, donde se incluyen la generación de listas.
#
#
# Version 3.0
#
# Esta actualización se produjo en 2008, una versión que tenía como propósito solucionar los fallos importantes en el diseño del lenguaje de programación (Tokio school, 2023).

# %%
import requests
from PIL import Image
from io import BytesIO

# URL de la imagen
url = "https://i.imgur.com/P2FTnjq.png"
# Descargar la imagen usando requests
response = requests.get(url)

# Abrir la imagen en Pillow
img = Image.open(BytesIO(response.content))

# Mostrar la imagen
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=928x460 at 0x7F097344FC10>

# %% [markdown]
# <A href="https://www.mclibre.org/consultar/python/otros/historia.html">Versiones disponibles de Python
# </A>

# %% [markdown]
# ##**Historia de Python en vídeo**

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lc5JJTQa4r8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lc5JJTQa4r8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# #**Referencias bibliográficas:**
#
#
# Tokio School. (2023). La historia de Python. Las versiones de un lenguaje único - Tokio School. https://www.tokioschool.com/formaciones/cursos-programacion/python/historia/
#
# Challenger-Pérez, I., Díaz-Ricardo, Y., & Becerra-García, R. A. (2014). El lenguaje de programación Python. Ciencias Holguín, 20(2), 1-13.
#
#
# Chazallet, S. (2016). Python 3: los fundamentos del lenguaje. Ediciones Eni.
